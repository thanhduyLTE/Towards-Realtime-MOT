# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhduyLTE/Towards-Realtime-MOT/blob/master/MOT_convertONNX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My\ Drive/Towards-Realtime-MOT
# mount to drive
# %cd /content/drive/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/Towards-Realtime-MOT

# %%
# !ls
# Out:
# assets		extract_ped_per_frame.py  result_thre_70.mp4  train.py
# cfg		LICENSE			  test.mp4	      utils
# data		models.py		  test.py	      weight1.pt
# DATASET_ZOO.md	__pycache__		  testVideo.mp4
# demo.py		README.md		  tracker
# docker		result_iou_70.mp4	  track.py

# %%
# !pip install motmetrics
# !pip install lap
# !pip install cython_bbox
# !pip install onnx
# Out:
# ...
#      |████████████████████████████████| 153kB 2.8MB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 71kB 6.2MB/s
# ...
#      |████████████████████████████████| 92kB 5.9MB/s
# ...
#      |████████████████████████████████| 51kB 5.3MB/s
# ...
#      |████████████████████████████████| 61kB 5.6MB/s
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-cp36-none-any.whl size=18684 sha256=851093c97d2fa0a7610a11b345c306398b5dcdac02e10fd10b6cd7749c3d7901
#   Stored in directory: /root/.cache/pip/wheels/01/7e/a9/b982d0fea22b7e4ae5619de949570cde5ad55420cec16e86a5
# Successfully built py-cpuinfo
# ERROR: pytest-benchmark 3.2.3 has requirement pytest>=3.8, but you'll have pytest 3.6.4 which is incompatible.
# ...
#      |████████████████████████████████| 1.5MB 2.8MB/s
# ...
#   Created wheel for lap: filename=lap-0.4.0-cp36-cp36m-linux_x86_64.whl size=1588997 sha256=af858bf54f40b185d2abf98f3f4a244e306109699561af68751731e4c73f4784
# ...

# %%
# !gdown https://drive.google.com/uc?id=1nlnuYfGNuHWZztQHXwVZSL_FvfE551pA -O weight1.pt
# !gdown  https://drive.google.com/uc?id=1UKgkYrsV-59kYaHgWeJ70p5Mij3QWuFr  -O weight2.pt
# !python demo.py --input-video TownCentreXVID.avi --weights weight1.pt --iou-thres 0.5  --conf-thres 0.5  --nms-thres 0.5  --min-box-area 200 --output-format video
# Out:
# Namespace(cfg='cfg/yolov3_1088x608.cfg', conf_thres=0.5, input_video='TownCentreXVID.avi', iou_thres=0.5, min_box_area=200.0, nms_thres=0.5, output_format='video', output_root='results', track_buffer=30, weights='weight1.pt')
#
# 2020-03-31 04:53:35 [INFO]: Starting tracking...
# Lenth of the video: 7500 frames
# 2020-03-31 04:53:55 [INFO]: Processing frame 0 (100000.00 fps)
# /gdrive/My Drive/Towards-Realtime-MOT/tracker/multitracker.py:142: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "tlbr_to_tlwh" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at /gdrive/My Drive/Towards-Realtime-MOT/tracker/multitracker.py (145)
#
# File "tracker/multitracker.py", line 145:
#     def tlbr_to_tlwh(tlbr):
#         ret = np.asarray(tlbr).copy()
#         ^
#
#   @staticmethod
# ...

# %%
from tracker.multitracker import JDETracker
from models import *

model = Darknet(opt.cfg, nID=14455)
opt = 
tracker = JDETracker(opt, frame_rate=frame_rate)
# Out:
# /gdrive/My Drive/Towards-Realtime-MOT
# [Errno 107] Transport endpoint is not connected: 'results'
# /gdrive/My Drive/Towards-Realtime-MOT
